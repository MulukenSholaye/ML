# %% [markdown]
# <a href="https://colab.research.google.com/github/MulukenSholaye/ML/blob/main/Copy_of_Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
import pandas as pd
import transformers
transformers.utils.logging.set_verbosity_error()

# prepare table + question
model_1 = "https://huggingface.co/datasets/togethercomputer/RedPajama-Data-V2"
model_2 = ""
data = {"Organization Name": ["Information Network Security Administration", "Ministry of Trade","Ministry of Finance", "Ministry of Revenues", "Toll Roads Enterprise","Ministry of Foreign Affairs"],
    "Organization Code": ["INSA","MoTR","MoF", "MoR", "ETRE","MoFA"],
        "type": ["Enterprise", "Enterprise","Enterprise", "Enterprise", "Private","Enterprise"],
        "Level": ["Agency", "Ministry","Ministry", "Ministry", "Private","Government"],  # Add "Government" to match length
        "Current CEO": ["Tigist Hamid", "Kasahun Gofe","Ahmed Shide", "Aynalem Niguse", "Abiy Yemataw","Temesgen Tiruneh"],
        "Number of employees": ["2000", "1400","3900", "1700", "300","3500"],
        "Business arena": ["Government", "Government","Government", "Government", "Private","Government"],
        "Revenue": ["45000","48000","67000","78000","80000","90000"],
        "City Location":["Addis Ababa","Addis Ababa","Addis Ababa","Addis Ababa","Addis Ababa","Addis Ababa"],
        "Location":["Wello Sefer","Gurd Shola","Sidist Kilo","Megenagna","Tulu Dimtu","Arat Kilo"],
        "Budget":["800000000","2800000000","7700000000","20500000000","300000000","300000000"],
        "About":["Works on cyber","Works on Trade related issues and regional integration","Finance of the ethiopia","Collects revenue and taxes","administer toll roads","relations between countires"]}

table = pd.DataFrame.from_dict(data)
table
# Out:
#                              Organization Name Organization Code        type  \
# 0  Information Network Security Administration              INSA  Enterprise
# 1                            Ministry of Trade              MoTR  Enterprise
# 2                          Ministry of Finance               MoF  Enterprise
# 3                         Ministry of Revenues               MoR  Enterprise
# 4                        Toll Roads Enterprise              ETRE     Private
# 5                  Ministry of Foreign Affairs              MoFA  Enterprise
#
#         Level       Current CEO Number of employees Business arena Revenue  \
# 0      Agency      Tigist Hamid                2000     Government   45000
# 1    Ministry      Kasahun Gofe                1400     Government   48000
# 2    Ministry       Ahmed Shide                3900     Government   67000
# 3    Ministry    Aynalem Niguse                1700     Government   78000
# ...

# %%
import streamlit as st
from langchain.llms import OpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains.question_answering import load_qa_chain
from langchain.document_loaders import PyPDFLoader, TextLoader
from PyPDF2 import PdfReader

# Streamlit UI
st.title("Document Question Answering App")

# Sidebar for OpenAI API key
with st.sidebar:
    openai_api_key = st.text_input("Enter your OpenAI API key:", type="password")

# File uploader
uploaded_file = st.file_uploader("Upload a PDF or txt file", type=["pdf", "txt"])

if uploaded_file is not None:
    # Process the file based on its

# %%
# !pip install streamlit transformers pypdf sentencepiece torch
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))

import streamlit as st
import torch
from transformers import pipeline, AutoModelForQuestionAnswering, AutoTokenizer
from pypdf import PdfReader

# Streamlit UI
st.title("Document Question Answering App")

# File uploader
uploaded_file = st.file_uploader("Upload a PDF or txt file", type=["pdf", "txt"])

if uploaded_file is not None:
    # Process the file based on its type
    if uploaded_file.type == "application/pdf":
        # Read PDF file
        pdf_reader = PdfReader(uploaded_file)
        text = ""
        for page in pdf_reader.pages:
            text += page.extract_text()
    else:
        # Read txt file
        text = uploaded_file.read().decode("utf-8")

    # Load the question answering pipeline
    model_name = "deepset/roberta-base-squad2"
    qa_pipeline = pipeline(
        "question-answering",
        model=AutoModelForQuestionAnswering.from_pretrained(model_name),
        tokenizer=AutoTokenizer.from_pretrained(model_name)
    )

    # Get user question
    question = st.text_input("Ask a question about the document:")

    if question:
        # Answer the question
        result = qa_pipeline({
            "question": question,
            "context": text
        })

        # Display the answer
        st.subheader("Answer")
        st.write(result["answer"])
# Out:
# ...
# Password/Enpoint IP for localtunnel is: 34.126.176.247

# %%
from transformers.utils import logging
logging.set_verbosity_error()

#question = "Which actor made the most number of movies?"
data = input('How can i help you please?')
if data:
  tqa = pipeline(task="table-question-answering", model="google/tapas-large-finetuned-wtq", tokenizer="google/tapas-large-finetuned-wtq")
  dat=tqa(table=table, query=data)['cells'][0]
    #print(tqa(table=table, query=data)['cells'][0])
  print(dat)
# Out:
# How can i help you please?Tell me about INSA
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.66k [00:00<?, ?B/s]
# TAPAS models are not usable since `tensorflow_probability` can't be loaded. It seems you have `tensorflow_probability` installed with the wrong tensorflow version. Please try to reinstall it following the instructions here: https://github.com/tensorflow/probability.
# model.safetensors:   0%|          | 0.00/1.35G [00:00<?, ?B/s]
# ...

# %%
# !streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.126.176.247:8501

# %%
from transformers.utils import logging
logging.set_verbosity_error()

#question = "Which actor made the most number of movies?"
data = input('How can i help you please?')
if data:
  tqa = pipeline(task="table-question-answering", model="google/tapas-large-finetuned-wtq", tokenizer="google/tapas-large-finetuned-wtq")
  # Convert table cells to strings
  table = table.astype(str)  # Convert all cells to strings
  print(tqa(table=table, query=data)['cells'][0])
# Out:
# How can i help you please?Tell me about ministry of agriculture
# /usr/local/lib/python3.10/dist-packages/transformers/models/tapas/tokenization_tapas.py:2673: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text = normalize_for_match(row[col_index].text)
# /usr/local/lib/python3.10/dist-packages/transformers/models/tapas/tokenization_tapas.py:1472: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell = row[col_index]
# The Ministry of Agriculture (MoA) is the Ethiopian government department which oversees the agricultural and rural development policies of Ethiopia on a federal level.

# %%
# !pip install streamlit
import streamlit as st

with st.sidebar:
    st.write("hello")
st.title("💬 Chatbot")
import streamlit as st
from openai import OpenAI

with st.sidebar:
    openai_api_key ="sfgdfsfessad45fsdfdsfdsfsdf4rrsfdsfsdfsfsefs"
    st.write(openai_api_key)
st.title("💬 Chatbot")

if "messages" not in st.session_state:
    st.session_state["messages"] = [{"role": "assistant", "content": "How can I help you?"}]

for msg in st.session_state.messages:
    st.chat_message(msg["role"]).write(msg["content"])

if prompt := st.chat_input():
    if not openai_api_key:
        st.info("Please add your OpenAI API key to continue.")
        st.stop()

    #client = OpenAI(api_key=openai_api_key)
    st.session_state.messages.append({"role": "user", "content": prompt})
    st.chat_message("user").write(prompt)
    response = client.chat.completions.create(model="gpt-3.5-turbo", messages=st.session_state.messages)
    msg = response.choices[0].message.content
    st.session_state.messages.append({"role": "assistant", "content": msg})
    st.chat_message("assistant").write(msg)

# %%
# !pip install streamlit transformers pandas
# !pip install --upgrade streamlit
import streamlit as st
import pandas as pd
from transformers import pipeline

# Load the table question answering pipeline
tqa = pipeline(task="table-question-answering",
               model="google/tapas-large-finetuned-wtq",
               tokenizer="google/tapas-large-finetuned-wtq")

# Streamlit app
st.title("Table Question Answering App")

# Upload CSV file
uploaded_file = st.file_uploader("Upload a CSV file", type=["csv"])

if uploaded_file is not None:
    # Read the CSV file into a Pandas DataFrame
    df = pd.read_csv(uploaded_file)

    # Display the DataFrame
    st.subheader("Uploaded Table")
    st.dataframe(df)

    # Get user question
    question = st.text_input("Ask a question about the table:")

    if question:
        # Convert table cells to strings
        df = df.astype(str)

        # Answer the question
        answer = tqa(table=df, query=question)['cells'][0]
        st.subheader("Answer")
        st.write(answer)

# Run the app
#if __name__ == "__main__":
#    st.set_page_config(page_title="Table Question Answering")
#    st.run()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 35.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...
